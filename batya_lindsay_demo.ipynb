# %%
from simulated_df import *

# Create simulated dataset

df = create_simulated_df(n_samp=500)

# %%
# Show first 10 items in dataframe, ordered by date

df.head(10)
# Out:
#                     people            topics      category       status  \
# date
# 2011_04  alexander_lindsay                NA      research       poster
# 2011_04                 NA      data_science      research  in_progress
# 2011_04    camacho_nicolas  machine_learning     cmi_staff           NA
# 2011_04         klein_arno  machine_learning      research       poster
# 2011_04    gregory_camille       psychopharm     cmi_staff  publication
# 2011_04       kramer_eliza       psychopharm      research  in_progress
# 2011_04                 NA       psychopharm            NA       poster
# 2011_04     septimus_batya  machine_learning     cmi_staff  publication
# 2011_04       kramer_eliza        psychology  presentation           NA
# 2011_04    gregory_camille       grad_school      resource           NA
#
#           datatypes database    difficulty
# date
# 2011_04       audio       NA      beginner
# 2011_04     genetic       NA            NA
# 2011_04          NA      fcp      advanced
# 2011_04       audio      hbn            NA
# 2011_04     genetic       NA  intermediate
# 2011_04  actigraphy      nki  intermediate
# 2011_04  behavioral       NA            NA
# 2011_04  actigraphy      hbn            NA
# 2011_04       audio       NA      advanced
# 2011_04         eeg  adhd200      beginner

# %%
# This is how the data in a CSV file would normally be loaded:

# df = pd.from_csv('/path/to/data/file.csv').sort_values('date')

# %%
# Filter by topic

filters, filtered_df = search_topic(df)
# Out:
# Here's a list of topics:
# ['NA',
#  'data_science',
#  'machine_learning',
#  'psychopharm',
#  'psychology',
#  'grad_school',
#  'medicine',
#  'coding',
#  'neuroscience']
# What topic are you interested in?: data_science
#
# Dataframe updated.

# %%
# Show first 10 items in updated dataframe, ordered by date

print(str('\nThere are {} results for your search term: {}.').
      format(filtered_df.shape[0], filters))

filtered_df.head(10)
# Out:
# There are 50 results for your search term: data_science.
#                   people        topics      category       status   datatypes  \
# date
# 2011_04               NA  data_science      research  in_progress     genetic
# 2011_04  camacho_nicolas  data_science            NA  in_progress     genetic
# 2011_04               NA  data_science  presentation  publication         eeg
# 2011_04     kramer_eliza  data_science     cmi_staff       poster  actigraphy
# 2013_09          xu_ting  data_science  presentation       poster          NA
# 2013_09               NA  data_science  presentation   proceeding  actigraphy
# 2013_09  gregory_camille  data_science  presentation   proceeding          NA
# 2014_05       klein_arno  data_science            NA  publication        fmri
# 2014_05     kramer_eliza  data_science      research  in_progress          NA
# 2014_05   septimus_batya  data_science      research           NA  actigraphy
#
#         database    difficulty
# date
# 2011_04       NA            NA
# 2011_04  adhd200  intermediate
# 2011_04      nki            NA
# 2011_04      nki            NA
# 2013_09       NA      beginner
# 2013_09  adhd200      beginner
# 2013_09  adhd200  intermediate
# 2014_05       NA            NA
# 2014_05      hbn      advanced
# 2014_05       NA      advanced

# %%
# Filter by datatype

filters, filtered_df = search_datatype(df)
# Out:
# Here's a list of datatypes:
# ['audio',
#  'genetic',
#  'NA',
#  'actigraphy',
#  'behavioral',
#  'eeg',
#  'fmri',
#  'eye_tracking']
# What datatypes are you interested in?: eeg
#
# Dataframe updated.

# %%
# Show first 10 items in updated dataframe, ordered by date

print(str('\nThere are {} results for your search term: {}.').
      format(filtered_df.shape[0], filters))

filtered_df.head(10)
# Out:
# There are 60 results for your search term: eeg.
#                   people            topics      category       status  \
# date
# 2011_04  gregory_camille       grad_school      resource           NA
# 2011_04     kramer_eliza       grad_school     cmi_staff  publication
# 2011_04               NA      data_science  presentation  publication
# 2011_04          xu_ting        psychology  presentation   proceeding
# 2011_04       klein_arno      neuroscience      resource   proceeding
# 2011_04          xu_ting                NA  presentation  in_progress
# 2011_04     koo_bonhwang  machine_learning     cmi_staff       poster
# 2013_09     kramer_eliza  machine_learning     cmi_staff  in_progress
# 2013_09          xu_ting          medicine      resource       poster
# 2013_09          xu_ting          medicine      research   proceeding
#
#         datatypes database    difficulty
# date
# 2011_04       eeg  adhd200      beginner
# 2011_04       eeg      hbn      advanced
# 2011_04       eeg      nki            NA
# 2011_04       eeg       NA      beginner
# 2011_04       eeg       NA  intermediate
# 2011_04       eeg  adhd200      advanced
# 2011_04       eeg      hbn  intermediate
# 2013_09       eeg      hbn  intermediate
# 2013_09       eeg  adhd200      beginner
# 2013_09       eeg  adhd200      beginner

# %%
# Filter by multiple features

filters, filtered_df = search_multiple(df, topics=True, category=False, status=False,
                                       datatypes=False, database=True, difficulty=False)
# Out:
# Here's a list of topics:
# ['NA',
#  'data_science',
#  'machine_learning',
#  'psychopharm',
#  'psychology',
#  'grad_school',
#  'medicine',
#  'coding',
#  'neuroscience']
# What topic are you interested in?: data_science
#
# Dataframe updated.
# Here's a list of databases
# ['NA', 'adhd200', 'nki', 'hbn', 'fcp']
# What datatypes are you interested in?: hbn
#
# Dataframe updated.

# %%
# Show first 10 items in updated dataframe, ordered by date

print(str('\nThere are {} results for your search terms: {}.').
      format(filtered_df.shape[0], filters))

filtered_df.head(10)
# Out:
# There are 14 results for your search terms: ['data_science', 'hbn'].
#                   people        topics      category       status  \
# date
# 2014_05     kramer_eliza  data_science      research  in_progress
# 2014_05  gregory_camille  data_science      research   proceeding
# 2015_01       klein_arno  data_science  presentation       poster
# 2015_01               NA  data_science     cmi_staff           NA
# 2017_07               NA  data_science      research  in_progress
# 2017_07     koo_bonhwang  data_science  presentation  in_progress
# 2017_07     kramer_eliza  data_science            NA       poster
# 2017_12      franco_alex  data_science      resource  in_progress
# 2017_12  camacho_nicolas  data_science      research           NA
# 2018_04     koo_bonhwang  data_science  presentation   proceeding
#
#             datatypes database difficulty
# date
# 2014_05            NA      hbn   advanced
# 2014_05       genetic      hbn         NA
# 2015_01            NA      hbn         NA
# 2015_01       genetic      hbn   advanced
# 2017_07          fmri      hbn         NA
# 2017_07    behavioral      hbn   beginner
# 2017_07  eye_tracking      hbn         NA
# 2017_12       genetic      hbn         NA
# 2017_12    actigraphy      hbn   beginner
# 2018_04            NA      hbn   beginner
